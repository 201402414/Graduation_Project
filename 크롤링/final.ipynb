# %% [markdown]
# ## 1. 페이지 for문<br>2. 게시물 별 url 이동 주소 저장<br>3. url 접근<br>4. div ul li 태그 접근<br>5. 이미지 경로 (~~~~/planemap) 찾아서 이미지 저장

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import urllib.request
import pandas as pd

# %%
driver = webdriver.Chrome("./chromedriver")
driver.get("https://www.r114.com/?_c=memul&_m=p10&direct=A")

# %%
driver.execute_script("goPage(1, 1)")

result_list = []
detail_url = []

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
for href in soup.find("ul", class_="list_article Best").find_all("li"):
    detail_url.append(href.find("a")["onclick"])
#     print(href.find("a")["onclick"])

# %%
list_test = []
detail_page = []
for i in range(len(detail_url)):
    list_test.append(detail_url[i][19:33])
#     print(list_test[i])

# %%
str123 = ""
for i in range(len(detail_url)):
    str123 = "https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=" + list_test[i]
    detail_page.append(str123)

# %%
for i in range(len(detail_page)):
        print(i+1)
        print(detail_page[i])
        print(" ")
# Out:
# 1
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=090A11AD782DBE
#
# 2
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00BF295360716A
#
# 3
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00DEC74DD73748
#
# 4
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00C522C350D372
#
# 5
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=09128863AEC38E
#
# 6
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=007AD6AE23F5A1
#
# 7
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00BAD2B1E8DBB7
#
# 8
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0957D61E373190
#
# 9
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0905A6C4FF385D
#
# 10
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01F3C3E3D44823
#
# 11
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=015BDBE1E71DB8
#
# 12
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01CDB83A349098
#
# 13
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=014D86766661AD
#
# 14
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01972C5F921249
#
# 15
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0172E726F0ABE1
#
# 16
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=013604EC8B596B
#
# 17
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=09982D065D0C48
#
# 18
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0058001C2DF12A
#
# 19
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=09BF8ABC78EAC1
#
# 20
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00432E23AE6C11
#
# 21
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=09F3B1F2B006C1
#
# 22
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=016D933FA9FACB
#
# 23
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0051425632280E
#
# 24
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=001083F9C62385
#
# 25
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01B093764DA2CA
#
# 26
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=015808B2BF3EB1
#
# 27
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01BB7D0663CB57
#
# 28
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0932FCDC7E65A3
#
# 29
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00E8C21FF1EECD
#
# 30
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=009FB4008ABD0A
#
# 31
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00B89BD490A4F5
#
# 32
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=016EDA0E7FDCE8
#
# 33
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0192DBED4593D4
#
# 34
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01C81118C714FF
#
# 35
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01E64AB0E37805
#
# 36
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=002B8DB6CF5BA7
#
# 37
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01F779C6378AFD
#
# 38
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=016B8F7C06C2D4
#
# 39
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01A16C399BCE1E
#
# 40
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=015535EE8CCE41
#
# 41
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01245C74E907B9
#
# 42
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=0151A2E794BE4D
#
# 43
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00095CE2FF25FE
#
# 44
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=013745AB490D08
#
# 45
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01077E79BAC7F2
#
# 46
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01939E5BE1F283
#
# 47
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=015F2E5865CD35
#
# 48
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=01689C30500713
#
# 49
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=00CA0FB59B3E49
#
# 50
# https://www.r114.com/?_c=memul&_m=HouseDetail&mulcode=09062E836ACB57

# %%
data = pd.DataFrame()

# %%
spninfo_list = []
spninfo = []
spndetail_text = []
spndetail_text_pd = [[]]
spninfo_pd=[[]]
temp=[]

# %%
a=1
for i in range(len(detail_page)):
    print(i+1)
    driver.get(detail_page[i])
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    soup_for_spninfo = BeautifulSoup(driver.page_source, 'html.parser')
    soup_for_spndetail = BeautifulSoup(driver.page_source, 'html.parser')

    if(soup.find("ul", class_="slider_cont")==None):
        print("슬라이드")##지우고 continue로 수정
        print("")##지워도됨
    else:
        soup = soup.find("ul", class_="slider_cont")
        if (soup.find("img", class_="Planemap")== None):
            print("No plane") #지우고 continue로 수정
            print("")         ##지워도됨
        else:   
            imgurl = soup.find("img", class_="Planemap")["src"]
            if (imgurl=="https://image.r114.co.kr/W1/images/r114/2011/noImage.gif"):
                print("no image")#지우고 continue로 수정
                print("")         ##지워도됨
            else:           #매물정보 넣을 위치
                print(imgurl)
                fname= "image/"+str(a).zfill(4)+".jpg"
                urllib.request.urlretrieve(imgurl,fname)
                #매물정보저장
                soup_for_spninfo = soup_for_spninfo.find("div", id="divMemulInfoTab")
                soup_for_spninfo = soup_for_spninfo.find("ul").find_all("span", class_="spninfo")
                for infoma in soup_for_spninfo:
                    spninfo_list.append(infoma)
#                 for i in range(0,8):
#                     spninfo.append(spninfo_list[i].next_element)
#                 spninfo.append("imgURL")
                
                #매물디테일저장
                soup_for_spndetail = soup_for_spndetail.find("div", id="divMemulInfoTab")
                soup_for_spndetail = soup_for_spndetail.find("ul").find_all("span", class_="spndetail")
#                 spndetail_text.append(soup_for_spndetail[0].next_element.next_element)
                spndetail_text.append(soup_for_spndetail[1].next_element.next_element)
                spndetail_text.append(soup_for_spndetail[2].next_element)
                spndetail_text.append(soup_for_spndetail[5].next_element)
                spndetail_text.append(soup_for_spndetail[6].next_element)
                if spninfo_list[7].next_element=='월관리비' :
                    spndetail_text.append(soup_for_spndetail[7].next_element)
                elif spninfo_list[8].next_element=='월관리비':
                    spndetail_text.append(soup_for_spndetail[8].next_element)
                elif spninfo_list[9].next_element=='월관리비':
                    spndetail_text.append(soup_for_spndetail[9].next_element)
                spndetail_text.append(fname)
              
    
                #합치기
                spndetail_text_pd = [spndetail_text]
                spninfo_pd = [spninfo]
#                 data = data.append(spninfo_pd)
                data = data.append(spndetail_text_pd)
                
                print(spndetail_text)
                
                spninfo = []
                spndetail_text = []
                spninfo_list=[]
                
                a=a+1
        print("")
# Out:
# 1
# No plane
#
#
# 2
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135270004300048z.gif
# ['115.63㎡', '75%', '3개 / 2개 ', '복합식', '500,000원', 'image/0001.jpg']
#
# 3
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135240001200023z.gif
# ['53.06㎡', '78%', '3개 / 1개 ', '복도식', '135,000원', 'image/0002.jpg']
#
# 4
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135280000800032z.gif
# ['84.58㎡', '78%', '3개 / 2개 ', '계단식', '330,000원', 'image/0003.jpg']
#
# 5
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280000600031z.gif
# ['95.27㎡', '93%', '3개 / 1개 ', '계단식', '300,000원', 'image/0004.jpg']
#
# 6
# 슬라이드
#
# 7
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135270004200068B.gif
# ['164.97㎡', '75%', '4개 / 2개 ', '복합식', '600,000원', 'image/0005.jpg']
#
# 8
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135280000800038z.gif
# ['97.35㎡', '78%', '4개 / 2개 ', '계단식', '380,000원', 'image/0006.jpg']
#
# 9
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135280000800026z.gif
# ['59.88㎡', '70%', '3개 / 1개 ', '복도식', '없음', 'image/0007.jpg']
#
# 10
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280000300031z.gif
# ['76.79㎡', '76%', '3개 / 1개 ', '복도식', '250,000원', 'image/0008.jpg']
#
# 11
# 슬라이드
#
# 12
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135190001900035B.gif
# ['84.92㎡', '73%', '3개 / 2개 ', '계단식', '180,000원', 'image/0009.jpg']
#
# 13
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135080005800046z.gif
# ['132.88㎡', '87%', '4개 / 2개 ', '계단식', '320,000원', 'image/0010.jpg']
#
# 14
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280000300031z.gif
# ['76.79㎡', '76%', '3개 / 1개 ', '복도식', '250,000원', 'image/0011.jpg']
#
# 15
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135080012700048A.gif
# ['136.28㎡', '84%', '4개 / 2개 ', '계단식', '400,000원', 'image/0012.jpg']
#
# 16
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135080008700024z.gif
# ['59.88㎡', '75%', '3개 / 2개 ', '계단식', '120,000원', 'image/0013.jpg']
#
# 17
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135270000400034z.gif
# ['84.97㎡', '75%', '3개 / 2개 ', '복도식', '260,000원', 'image/0014.jpg']
#
# 18
# No plane
#
#
# 19
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280003400031z.gif
# ['95.48㎡', '93%', '3개 / 1개 ', '계단식', '300,000원', 'image/0015.jpg']
#
# 20
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280001300053z.gif
# ['162.71㎡', '94%', '5개 / 2개 ', '계단식', '450,000원', 'image/0016.jpg']
#
# 21
# No plane
#
#
# 22
# No plane
#
#
# 23
# No plane
#
#
# 24
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135080010200049c.gif
# ['131.38㎡', '80%', '4개 / 2개 ', '계단식', '400,000원', 'image/0017.jpg']
#
# 25
# 슬라이드
#
# 26
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135080005800047z.gif
# ['133.95㎡', '86%', '4개 / 2개 ', '계단식', '없음', 'image/0018.jpg']
#
# 27
# No plane
#
#
# 28
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135090015500034B.gif
# ['84.95㎡', '76%', '3개 / 2개 ', '계단식', '없음', 'image/0019.jpg']
#
# 29
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280000500035z.gif
# ['84.96㎡', '74%', '3개 / 1개 ', '복도식', '없음', 'image/0020.jpg']
#
# 30
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135280000100057z.gif
# ['161.36㎡', '85%', '4개 / 2개 ', '계단식', '없음', 'image/0021.jpg']
#
# 31
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135270008400054z.gif
# ['155.97㎡', '87%', '4개 / 2개 ', '계단식', '450,000원', 'image/0022.jpg']
#
# 32
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135090011400062z.gif
# ['142.31㎡', '91%', '4개 / 2개 ', '계단식', '없음', 'image/0023.jpg']
#
# 33
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135100003800040z.gif
# ['107.22㎡', '81%', '4개 / 2개 ', '계단식', '없음', 'image/0024.jpg']
#
# 34
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135100003000025z.gif
# ['59.97㎡', '72%', '3개 / 1개 ', '복합식', '150,000원', 'image/0025.jpg']
#
# 35
# No plane
#
#
# 36
# No plane
#
#
# 37
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135100007800041A.gif
# ['113.21㎡', '82%', '4개 / 2개 ', '계단식', '200,000원', 'image/0026.jpg']
#
# 38
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135100007800037b.gif
# ['102.26㎡', '82%', '3개 / 2개 ', '계단식', '150,000원', 'image/0027.jpg']
#
# 39
# https://image.r114.co.kr/imgdata/planemap/01/01/A0101135110002000043z.gif
# ['131.48㎡', '93%', '4개 / 2개 ', '복도식', '200,000원', 'image/0028.jpg']
#
# 40
# https://image.r114.co.kr/imgdata/planemap2/a0101135100010000021C.gif
# ['49.59㎡', '70%', '2개 / 1개 ', '복도식', '150,000원', 'image/0029.jpg']
#
# 41
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135100004200056B.gif
# ['157.2㎡', '84%', '5개 / 3개 ', '계단식', '300,000원', 'image/0030.jpg']
#
# 42
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135110001600054z.gif
# ['163.67㎡', '92%', '5개 / 2개 ', '계단식', '250,000원', 'image/0031.jpg']
#
# 43
# No plane
#
#
# 44
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135100003800040z.gif
# ['107.22㎡', '81%', '4개 / 2개 ', '계단식', '200,000원', 'image/0032.jpg']
#
# 45
# No plane
#
#
# 46
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135090009900044A.gif
# ['122.48㎡', '83%', '4개 / 2개 ', '계단식', '200,000원', 'image/0033.jpg']
#
# 47
# https://image.r114.co.kr/imgdata/planemap2/a0101135090012900033A.gif
# ['84.23㎡', '77%', '3개 / 2개 ', '계단식', '150,000원', 'image/0034.jpg']
#
# 48
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135090003100042z.gif
# ['113㎡', '81%', '4개 / 2개 ', '계단식', '200,000원', 'image/0035.jpg']
#
# 49
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135280005200053z.gif
# ['145.83㎡', '82%', '4개 / 2개 ', '계단식', '없음', 'image/0036.jpg']
#
# 50
# https://image.r114.co.kr/imgdata/planemap/01/01/a0101135280001300031z.gif
# ['96.04㎡', '94%', '3개 / 1개 ', '계단식', '250,000원', 'image/0037.jpg']

# %%
data
# Out:
#          0    1         2    3         4
# 0  155.97㎡  87%  4개 / 2개   계단식  450,000원
# 0  142.31㎡  91%  4개 / 2개   계단식        없음
# 0  107.22㎡  81%  4개 / 2개   계단식        없음
# 0    59.7㎡  75%  3개 / 1개   복도식        없음
# 0  163.67㎡  92%  5개 / 2개   계단식  250,000원
# 0  102.26㎡  82%  3개 / 2개   계단식  150,000원
# 0   157.2㎡  84%  5개 / 3개   계단식  300,000원
# 0   59.97㎡  72%  3개 / 1개   복합식  150,000원
# 0   49.59㎡  70%  2개 / 1개   복도식  150,000원
# 0  131.48㎡  93%  4개 / 2개   복도식  200,000원
# 0  107.22㎡  81%  4개 / 2개   계단식  200,000원
# 0   84.78㎡  78%  3개 / 2개   복합식  150,000원
# 0   96.04㎡  94%  3개 / 1개   계단식  250,000원
# 0  133.71㎡  86%  4개 / 2개   계단식  250,000원
# 0  161.47㎡  80%  5개 / 3개   계단식        없음
# 0   84.95㎡  76%  3개 / 2개   계단식  150,000원
# 0  161.47㎡  80%  5개 / 3개   계단식        없음
# 0   84.23㎡  77%  3개 / 2개   계단식  150,000원
# 0  145.83㎡  82%  4개 / 2개   계단식        없음
# 0     113㎡  81%  4개 / 2개   계단식  200,000원
# 0   58.57㎡  74%  2개 / 1개   복도식  120,000원
# 0   31.40㎡  66%  1개 / 1개   계단식  100,000원
# 0  122.48㎡  83%  4개 / 2개   계단식  200,000원
# 0   84.23㎡  77%  3개 / 2개   계단식  150,000원
# 0   59.88㎡  70%  3개 / 1개   복도식  120,000원
# 0   95.48㎡  93%  3개 / 1개   계단식  300,000원
# 0   84.96㎡  74%  3개 / 1개   복도식        없음
# 0  132.05㎡  93%  4개 / 2개   계단식  400,000원
# 0   95.27㎡  93%  3개 / 1개   계단식  250,000원
# 0  125.17㎡  93%  4개 / 2개   계단식  400,000원
# 0  158.54㎡  87%  5개 / 2개   계단식  478,000원
# 0   28.24㎡  78%  1개 / 1개   복도식   80,000원
# 0   28.24㎡  78%  1개 / 1개   복합식   80,000원
# 0   97.35㎡  78%  4개 / 2개   계단식  155,000원
# 0   84.97㎡  75%  3개 / 2개   계단식  370,000원
# 0  131.38㎡  80%  4개 / 2개   계단식        없음
# 0   94.49㎡  75%  3개 / 2개   계단식  496,000원
# 0  127.75㎡  86%  4개 / 2개   계단식  470,000원

# %%
import math

# %%
bb = data[0]
cc = data[1]
aa = data[2]
dd = data[3]
ee = data[4]
ff = data[5]
main_area = []
bedroom = []
bath = []
con_rate = []
porch_structure = []
administrative_expenses = []
img_url = []

for i in range(len(ff)):
    img_url.append(ff.values[i])
for i in range(len(bb)):
    bb.values[i] = bb.values[i].rstrip('㎡')
    bb.values[i]= math.trunc(float(bb.values[i]))
    main_area.append(bb.values[i])

for i in range(len(cc)):
    con_rate.append(float(cc.values[i].rstrip('%')))

for i in range(len(ee)):
    if ee.values[i] == '없음':
        administrative_expenses .append(float(0))
        continue
    ee.values[i] = ee.values[i].rstrip('원')
    ee.values[i] = ee.values[i].replace(',', '')
    administrative_expenses .append(float(ee.values[i]))
    

for i in range(len(aa)):
    bedroom.append(float(aa.values[i][0]))
    bath.append(float(aa.values[i][5]))


for i in range(len(aa)):
    bedroom.append(float(aa.values[i][0]))
    bath.append(float(aa.values[i][5]))

for i in range(len(dd)):
    if dd.values[i] == '복도식':
        porch_structure.append(int(0))
    elif dd.values[i] == '계단식':
        porch_structure.append(int(1))
    elif dd.values[i] == '복합식':
        porch_structure.append(int(2))

# %%
data2 = pd.DataFrame()

data2.loc[:, "con_rate"] = pd.Series(con_rate)
data2.loc[:, "bedroom"] = pd.Series(bedroom)
data2.loc[:, "bath"] = pd.Series(bath)
data2.loc[:, "porch_structure"] = pd.Series(porch_structure)
data2.loc[:, "administrative_expenses"] = pd.Series(administrative_expenses)
data2.loc[:, "main_area"] = pd.Series(main_area)
data2.loc[:, "img_url"] = pd.Series(img_url)

non_expense = data2[data2["administrative_expenses"] == 0.0].index
data2 = data2.drop(non_expense)

# %%
data2
# Out:
#     con_rate  bath  porch_structure  administrative_expenses  main_area  \
# 0       87.0   2.0                1                 450000.0        155
# 4       92.0   2.0                1                 250000.0        163
# 5       82.0   2.0                1                 150000.0        102
# 6       84.0   3.0                1                 300000.0        157
# 7       72.0   1.0                2                 150000.0         59
# 8       70.0   1.0                0                 150000.0         49
# 9       93.0   2.0                0                 200000.0        131
# 10      81.0   2.0                1                 200000.0        107
# 11      78.0   2.0                2                 150000.0         84
# 12      94.0   1.0                1                 250000.0         96
# 13      86.0   2.0                1                 250000.0        133
# 15      76.0   2.0                1                 150000.0         84
# 17      77.0   2.0                1                 150000.0         84
# 19      81.0   2.0                1                 200000.0        113
# 20      74.0   1.0                0                 120000.0         58
# 21      66.0   1.0                1                 100000.0         31
# 22      83.0   2.0                1                 200000.0        122
# 23      77.0   2.0                1                 150000.0         84
# 24      70.0   1.0                0                 120000.0         59
# 25      93.0   1.0                1                 300000.0         95
# 27      93.0   2.0                1                 400000.0        132
# 28      93.0   1.0                1                 250000.0         95
# 29      93.0   2.0                1                 400000.0        125
# 30      87.0   2.0                1                 478000.0        158
# 31      78.0   1.0                0                  80000.0         28
# 32      78.0   1.0                2                  80000.0         28
# 33      78.0   2.0                1                 155000.0         97
# 34      75.0   2.0                1                 370000.0         84
# 36      75.0   2.0                1                 496000.0         94
# 37      86.0   2.0                1                 470000.0        127
#
#     bedroom
# 0       4.0
# 4       5.0
# 5       3.0
# 6       5.0
# 7       3.0
# 8       2.0
# 9       4.0
# 10      4.0
# 11      3.0
# 12      3.0
# 13      4.0
# 15      3.0
# 17      3.0
# 19      4.0
# 20      2.0
# 21      1.0
# 22      4.0
# 23      3.0
# 24      3.0
# 25      3.0
# 27      4.0
# 28      3.0
# 29      4.0
# 30      5.0
# 31      1.0
# 32      1.0
# 33      4.0
# 34      3.0
# 36      3.0
# 37      4.0

# %%
data2.to_csv('map_info.csv')
